# %%
import os
import pandas as pd
import json

# %%
#  Mapping to match map's state spelling
state_name_mapping = {
    "andaman-&-nicobar-islands": "Andaman & Nicobar",
    "andhra-pradesh": "Andhra Pradesh",
    "arunachal-pradesh": "Arunachal Pradesh",
    "assam": "Assam",
    "bihar": "Bihar",
    "chandigarh": "Chandigarh",
    "chhattisgarh": "Chhattisgarh",
    "dadra-&-nagar-haveli-&-daman-&-diu": "Dadra and Nagar Haveli and Daman and Diu",
    "delhi": "NCT of Delhi",
    "goa": "Goa",
    "gujarat": "Gujarat",
    "haryana": "Haryana",
    "himachal-pradesh": "Himachal Pradesh",
    "jammu-&-kashmir": "Jammu & Kashmir",
    "jharkhand": "Jharkhand",
    "karnataka": "Karnataka",
    "kerala": "Kerala",
    "ladakh": "Ladakh",
    "lakshadweep": "Lakshadweep",
    "madhya-pradesh": "Madhya Pradesh",
    "maharashtra": "Maharashtra",
    "manipur": "Manipur",
    "meghalaya": "Meghalaya",
    "mizoram": "Mizoram",
    "nagaland": "Nagaland",
    "odisha": "Odisha",
    "puducherry": "Puducherry",
    "punjab": "Punjab",
    "rajasthan": "Rajasthan",
    "sikkim": "Sikkim",
    "tamil-nadu": "Tamil Nadu",
    "telangana": "Telangana",
    "tripura": "Tripura",
    "uttar-pradesh": "Uttar Pradesh",
    "uttarakhand": "Uttarakhand",
    "west-bengal": "West Bengal"
}

# AGGREGATED INSURANCE
path="E:\\VSCODE\\PhonePeTransactionInsights\\pulse\\data\\aggregated\\insurance\\country\\india\\state\\"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Insurance_type':[], 'Insurance_count':[], 'Insurance_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Insurance_type'].append(Name)
              clm['Insurance_count'].append(count)
              clm['Insurance_amount'].append(amount)
              clm['State'].append(state_name_mapping.get(i, i))
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))

Agg_insur=pd.DataFrame(clm)

# AGGREGATED TRANSACTION
path="E:\\VSCODE\\PhonePeTransactionInsights\\pulse\\data\\aggregated\\transaction\\country\\india\\state\\"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(state_name_mapping.get(i, i))
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))

Agg_trans=pd.DataFrame(clm)

# AGGREGATED USER
path="E:\\VSCODE\\PhonePeTransactionInsights\\pulse\\data\\aggregated\\user\\country\\india\\state\\"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Brands':[], 'Transaction_count':[], 'Percentage':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)

            try:
                for z in D['data']['usersByDevice']:
                    brand=z['brand']
                    count=z['count']
                    percentage=z['percentage']
                    clm['Brands'].append(brand)
                    clm['Transaction_count'].append(count)
                    clm['Percentage'].append(percentage)
                    clm['State'].append(state_name_mapping.get(i, i))
                    clm['Year'].append(j)
                    clm['Quater'].append(int(k.strip('.json')))
            except:
                pass

Agg_user=pd.DataFrame(clm)

# MAP INSURANCE
path="E:\\VSCODE\\PhonePeTransactionInsights\\pulse\\data\\map\\insurance\\hover\\country\\india\\state\\"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Districts':[], 'Insurance_count':[], 'Insurance_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Districts'].append(Name)
              clm['Insurance_count'].append(count)
              clm['Insurance_amount'].append(amount)
              clm['State'].append(state_name_mapping.get(i, i))
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))

Map_insur=pd.DataFrame(clm)

# MAP TRANSACTION
path="E:\\VSCODE\\PhonePeTransactionInsights\\pulse\\data\\map\\transaction\\hover\\country\\india\\state\\"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Districts':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Districts'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(state_name_mapping.get(i, i))
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))

Map_trans=pd.DataFrame(clm)

# MAP USER
path="E:\\VSCODE\\PhonePeTransactionInsights\\pulse\\data\\map\\user\\hover\\country\\india\\state\\"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Districts':[], 'RegisteredUser':[], 'AppOpens':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)

            for z in D['data']['hoverData'].items():
                district = z[0]
                registereduser = z[1]["registeredUsers"]
                appopens = z[1]["appOpens"]
                clm['Districts'].append(district)
                clm['RegisteredUser'].append(registereduser)
                clm['AppOpens'].append(appopens)
                clm['State'].append(state_name_mapping.get(i, i))
                clm['Year'].append(j)
                clm['Quater'].append(int(k.strip('.json')))

Map_user=pd.DataFrame(clm)

# TOP INSURANCE
path="E:\\VSCODE\\PhonePeTransactionInsights\\pulse\\data\\top\\insurance\\country\\india\\state\\"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Pincodes':[], 'Insurance_count':[], 'Insurance_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['pincodes']:
              entityName = z["entityName"]
              count = z["metric"]["count"]
              amount = z["metric"]["amount"]
              clm['Pincodes'].append(entityName)
              clm['Insurance_count'].append(count)
              clm['Insurance_amount'].append(amount)
              clm['State'].append(state_name_mapping.get(i, i))
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))

Top_insur=pd.DataFrame(clm)

# TOP TRANSACTION 
path="E:\\VSCODE\\PhonePeTransactionInsights\\pulse\\data\\top\\transaction\\country\\india\\state\\"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Pincodes':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['pincodes']:
              entityName = z["entityName"]
              count = z["metric"]["count"]
              amount = z["metric"]["amount"]
              clm['Pincodes'].append(entityName)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(state_name_mapping.get(i, i))
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))

Top_trans=pd.DataFrame(clm)

#  TOP USER 
path="E:\\VSCODE\\PhonePeTransactionInsights\\pulse\\data\\top\\user\\country\\india\\state\\"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Pincodes':[], 'RegisteredUser':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)

            for z in D['data']['pincodes']:
                    name = z["name"]
                    registereduser = z["registeredUsers"]
                    clm['Pincodes'].append(name)
                    clm['RegisteredUser'].append(registereduser)
                    clm['State'].append(state_name_mapping.get(i, i))
                    clm['Year'].append(j)
                    clm['Quater'].append(int(k.strip('.json')))

Top_user=pd.DataFrame(clm)

# %%
import mysql.connector
mydb = mysql.connector.connect(
        host = "127.0.0.1",
        user = "root",
        password = "Pasupathi@1710",
        database = "phonepe",
        autocommit = True)
cursor = mydb.cursor()


cursor.execute("""
            CREATE TABLE IF NOT EXISTS aggregated_insurance(
            States VARCHAR(50),
                    Years INT,
                    Quarter INT,
                    Insurance_type VARCHAR(50),
                    Insurance_count BIGINT,
                    Insurance_amount BIGINT)
        """)

query = "INSERT INTO aggregated_insurance (States, Years, Quarter, Insurance_type, Insurance_count, Insurance_amount) VALUES (%s, %s, %s, %s, %s, %s)"
values = [tuple(x) for x in Agg_insur.to_numpy()]
cursor.executemany(query, values)

cursor.execute("""
            CREATE TABLE IF NOT EXISTS aggregated_transaction(
            States VARCHAR(50),
                    Years INT,
                    Quarter INT,
                    Transaction_type VARCHAR(50),
                    Transaction_count BIGINT,
                    Transaction_amount BIGINT)
        """)

query = "INSERT INTO aggregated_transaction (States, Years, Quarter, Transaction_type, Transaction_count, Transaction_amount) VALUES (%s, %s, %s, %s, %s, %s)"
values = [tuple(x) for x in Agg_trans.to_numpy()]
cursor.executemany(query, values)

cursor.execute("""
            CREATE TABLE IF NOT EXISTS aggregated_user(
            States VARCHAR(50),
                    Years INT,
                    Quarter INT,
                    Brands VARCHAR(50),
                    Transaction_count BIGINT,
                    Percentage FLOAT)
        """)

query = "INSERT INTO aggregated_user (States, Years, Quarter, Brands, Transaction_count, Percentage) VALUES (%s, %s, %s, %s, %s, %s)"
values = [tuple(x) for x in Agg_user.to_numpy()]
cursor.executemany(query, values)


cursor.execute("""
            CREATE TABLE IF NOT EXISTS map_insurance(
            States VARCHAR(50),
                    Years INT,
                    Quarter INT,
                    District VARCHAR(50),
                    Transaction_count BIGINT,
                    Transaction_amount FLOAT)
        """)

query = "INSERT INTO map_insurance (States, Years, Quarter, District, Transaction_count, Transaction_amount) VALUES (%s, %s, %s, %s, %s, %s)"
values = [tuple(x) for x in Map_insur.to_numpy()]
cursor.executemany(query, values)




cursor.execute("""
            CREATE TABLE IF NOT EXISTS map_transaction(
            States VARCHAR(50),
                    Years INT,
                    Quarter INT,
                    District VARCHAR(50),
                    Transaction_count BIGINT,
                    Transaction_amount FLOAT)
        """)

query = "INSERT INTO map_transaction (States, Years, Quarter, District, Transaction_count, Transaction_amount) VALUES (%s, %s, %s, %s, %s, %s)"
values = [tuple(x) for x in Map_trans.to_numpy()]
cursor.executemany(query, values)


cursor.execute("""
            CREATE TABLE IF NOT EXISTS map_user(
            States VARCHAR(50),
                    Years INT,
                    Quarter INT,
                    District VARCHAR(50),
                    RegisteredUser BIGINT,
                    AppOpens BIGINT)
        """)

query = "INSERT INTO map_user (States, Years, Quarter, District, RegisteredUser, AppOpens) VALUES (%s, %s, %s, %s, %s, %s)"
values = [tuple(x) for x in Map_user.to_numpy()]
cursor.executemany(query, values)

cursor.execute("""
            CREATE TABLE IF NOT EXISTS top_insurance(
            States VARCHAR(50),
                    Years INT,
                    Quarter INT,
                    Pincodes INT,
                    Transaction_count BIGINT,
                    Transaction_amount BIGINT)
        """)


query = "INSERT INTO top_insurance (States, Years, Quarter, Pincodes, Transaction_count, Transaction_amount) VALUES (%s, %s, %s, %s, %s, %s)"
values = [tuple(x) for x in Top_insur.to_numpy()]
cursor.executemany(query, values)


cursor.execute("""
            CREATE TABLE IF NOT EXISTS top_transaction(
            States VARCHAR(50),
                    Years INT,
                    Quarter INT,
                    Pincodes INT,
                    Transaction_count BIGINT,
                    Transaction_amount BIGINT)
        """)

query = "INSERT INTO top_transaction (States, Years, Quarter, Pincodes, Transaction_count, Transaction_amount) VALUES (%s, %s, %s, %s, %s, %s)"
values = [tuple(x) for x in Top_trans.to_numpy()]
cursor.executemany(query, values)

cursor.execute("""
            CREATE TABLE IF NOT EXISTS top_user(
            States VARCHAR(50),
                    Years INT,
                    Quarter INT,
                    Pincodes INT,
                    RegisteredUser BIGINT)
        """)

query = "INSERT INTO top_user (States, Years, Quarter, Pincodes, RegisteredUser) VALUES (%s, %s, %s, %s, %s)"
values = [tuple(x) for x in Top_user.to_numpy()]
cursor.executemany(query, values)
